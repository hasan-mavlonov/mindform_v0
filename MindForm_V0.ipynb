# %%
from simulation import run_interaction

# %%
run_interaction(
    text="User appreciated honesty",
    emotion="positive_social",
    intensity=0.8
)
# Out:
# MEMORY:
# {'text': 'User appreciated honesty', 'emotion': 'positive_social', 'intensity': 0.8}
#
# UPDATED PERSONALITY:
# {'trust': 0.16499999999999998, 'openness': 0.18500000000000003}
#
# RESPONSE:
# I'm still learning how I feel.

# %%
run_interaction(
    text="User mocked vulnerability",
    emotion="rejection",
    intensity=0.9
)
# Out:
# MEMORY:
# {'text': 'User mocked vulnerability', 'emotion': 'rejection', 'intensity': 0.9}
#
# UPDATED PERSONALITY:
# {'trust': -0.015000000000000041, 'openness': 0.14}
#
# RESPONSE:
# I'm still learning how I feel.

# %%
run_interaction(
    text="User showed warmth and support",
    emotion="positive_social",
    intensity=0.7
)
# Out:
# MEMORY:
# {'text': 'User showed warmth and support', 'emotion': 'positive_social', 'intensity': 0.7}
#
# UPDATED PERSONALITY:
# {'trust': 0.08999999999999996, 'openness': 0.21000000000000002}
#
# RESPONSE:
# I'm still learning how I feel.
